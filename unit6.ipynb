# %% [markdown]
# # Unit 6: Advantage Actor Critic (A2C) using Robotics Simulations with PyBullet and Panda-Gym 🤖
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit8/thumbnail.png"  alt="Thumbnail"/>
#
# In this notebook, you'll learn to use A2C with PyBullet and Panda-Gym, two set of robotics environments.
#
# With [PyBullet](https://github.com/bulletphysics/bullet3), you're going to **train a robot to move**:
# - `AntBulletEnv-v0` 🕸️ More precisely, a spider (they say Ant but come on... it's a spider 😆) 🕸️
#
# Then, with [Panda-Gym](https://github.com/qgallouedec/panda-gym), you're going **to train a robotic arm** (Franka Emika Panda robot) to perform a task:
# - `Reach`: the robot must place its end-effector at a target position.
#
# After that, you'll be able **to train in other robotics environments**.

# %% [markdown]
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit8/environments.gif" alt="Robotics environments"/>

# %% [markdown]
# ### 🎮 Environments:
#
# - [PyBullet](https://github.com/bulletphysics/bullet3)
# - [Panda-Gym](https://github.com/qgallouedec/panda-gym)
#
# ###📚 RL-Library:
#
# - [Stable-Baselines3](https://stable-baselines3.readthedocs.io/)

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the GitHub Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# ## Objectives of this notebook 🏆
#
# At the end of the notebook, you will:
#
# - Be able to use **PyBullet** and **Panda-Gym**, the environment libraries.
# - Be able to **train robots using A2C**.
# - Understand why **we need to normalize the input**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from the Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>
#
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 Study [Actor-Critic methods by reading Unit 6](https://huggingface.co/deep-rl-course/unit6/introduction) 🤗

# %% [markdown]
# # Let's train our first robots 🤖

# %% [markdown]
# To validate this hands-on for the [certification process](https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process),  you need to push your two trained models to the Hub and get the following results:
#
# - `AntBulletEnv-v0` get a result of >= 650.
# - `PandaReachDense-v2` get a result of >= -3.5.
#
# To find your result, go to the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) and find your model, **the result = mean_reward - std of reward**
#
# If you don't find your model, **go to the bottom of the page and click on the refresh button**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# ## Create a virtual display 🔽
#
# During the notebook, we'll need to generate a replay video. To do so, with colab, **we need to have a virtual screen to be able to render the environment** (and thus record the frames).
#
# Hence the following cell will install the librairies and create and run a virtual screen 🖥

# %%
# %%capture
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ### Install dependencies 🔽
# The first step is to install the dependencies, we’ll install multiple ones:
#
# - `pybullet`: Contains the walking robots environments.
# - `panda-gym`: Contains the robotics arm environments.
# - `stable-baselines3[extra]`: The SB3 deep reinforcement learning library.
# - `huggingface_sb3`: Additional code for Stable-baselines3 to load and upload models from the Hugging Face 🤗 Hub.
# - `huggingface_hub`: Library allowing anyone to work with the Hub repositories.

# %%
# Install the specific setuptools version required to install the dependencies
# %pip install setuptools==65.5.0

# %%
# %pip install -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt

# %% [markdown]
# ## Import the packages 📦

# %%
import pybullet_envs
import panda_gym
import gym

import os

from huggingface_sb3 import load_from_hub, package_to_hub

from stable_baselines3 import A2C
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.env_util import make_vec_env

from huggingface_hub import notebook_login

# %% [markdown]
# ## Environment 1: AntBulletEnv-v0 🕸

# %% [markdown]
# ### Create the AntBulletEnv-v0
# #### The environment 🎮
# In this environment, the agent needs to use correctly its different joints to walk correctly.
# You can find a detailled explanation of this environment here: https://hackmd.io/@jeffreymo/SJJrSJh5_#PyBullet

# %%
env_id = "AntBulletEnv-v0"
# Create the env
env = gym.make(env_id)

# Get the state space and action space
s_size = env.observation_space.shape[0]
a_size = env.action_space

# %%
print("_____OBSERVATION SPACE_____ \n")
print("The State Space is: ", s_size)
print("Sample observation", env.observation_space.sample()) # Get a random observation

# %% [markdown]
# The observation Space (from [Jeffrey Y Mo](https://hackmd.io/@jeffreymo/SJJrSJh5_#PyBullet)):
#
# The difference is that our observation space is 28 not 29.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit8/obs_space.png" alt="PyBullet Ant Obs space"/>

# %%
print("\n _____ACTION SPACE_____ \n")
print("The Action Space is: ", a_size)
print("Action Space Sample", env.action_space.sample()) # Take a random action

# %% [markdown]
# The action Space (from [Jeffrey Y Mo](https://hackmd.io/@jeffreymo/SJJrSJh5_#PyBullet)):
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit8/action_space.png" alt="PyBullet Ant Obs space"/>

# %% [markdown]
# ### Normalize observation and rewards

# %% [markdown]
# A good practice in reinforcement learning is to [normalize input features](https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html).
#
# For that purpose, there is a wrapper that will compute a running average and standard deviation of input features.
#
# We also normalize rewards with this same wrapper by adding `norm_reward = True`
#
# [You should check the documentation to fill this cell](https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecnormalize)

# %%
env = make_vec_env(env_id, n_envs=4)

# Adding this wrapper to normalize the observation and the reward
# TODO: Add the wrapper
env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.0)

# %% [markdown]
# #### Solution

# %%
env = make_vec_env(env_id, n_envs=4)

env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

# %% [markdown]
# ### Create the A2C Model 🤖
#
# In this case, because we have a vector of 28 values as input, we'll use an MLP (multi-layer perceptron) as policy.
#
# For more information about A2C implementation with StableBaselines3 check: https://stable-baselines3.readthedocs.io/en/master/modules/a2c.html#notes
#
# To find the best parameters I checked the [official trained agents by Stable-Baselines3 team](https://huggingface.co/sb3).

# %%
model = A2C(policy="MlpPolicy",
            env = env,
            gae_lambda = 0.9,
            gamma = 0.99,
            learning_rate = 0.00096,
            max_grad_norm = 0.5,
            n_steps = 8,
            vf_coef = 0.4,
            ent_coef = 0.0,
            policy_kwargs=dict(
            log_std_init=-2, ortho_init=False),
            normalize_advantage=False,
            use_rms_prop= True,
            use_sde= True,
            verbose=1)

# %% [markdown]
# #### Solution

# %%
model = A2C(policy = "MlpPolicy",
            env = env,
            gae_lambda = 0.9,
            gamma = 0.99,
            learning_rate = 0.00096,
            max_grad_norm = 0.5,
            n_steps = 8,
            vf_coef = 0.4,
            ent_coef = 0.0,
            policy_kwargs=dict(
            log_std_init=-2, ortho_init=False),
            normalize_advantage=False,
            use_rms_prop= True,
            use_sde= True,
            verbose=1)

# %% [markdown]
# ### Train the A2C agent 🏃
# - Let's train our agent for 2,000,000 timesteps, don't forget to use GPU on Colab. It will take approximately ~25-40min

# %%
model.learn(2_000_000)

# %%
# Save the model and  VecNormalize statistics when saving the agent
model.save("a2c-AntBulletEnv-v0")
env.save("vec_normalize.pkl")

# %% [markdown]
# ### Evaluate the agent 📈
# - Now that's our  agent is trained, we need to **check its performance**.
# - Stable-Baselines3 provides a method to do that: `evaluate_policy`
# - In my case, I got a mean reward of `2371.90 +/- 16.50`

# %%
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

# Load the saved statistics
eval_env = DummyVecEnv([lambda: gym.make("AntBulletEnv-v0")])
eval_env = VecNormalize.load("vec_normalize.pkl", eval_env)

#  do not update them at test time
eval_env.training = False
# reward normalization is not needed at test time
eval_env.norm_reward = False

# Load the agent
model = A2C.load("a2c-AntBulletEnv-v0")

mean_reward, std_reward = evaluate_policy(model, eval_env)

print(f"Mean reward = {mean_reward:.2f} +/- {std_reward:.2f}")

# %% [markdown]
# ### Publish your trained model on the Hub 🔥
# Now that we saw we got good results after the training, we can publish our trained model on the Hub with one line of code.
#
# 📚 The libraries documentation 👉 https://github.com/huggingface/huggingface_sb3/tree/main#hugging-face--x-stable-baselines3-v20
#
# Here's an example of a Model Card (with a PyBullet environment):
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit8/modelcardpybullet.png" alt="Model Card Pybullet"/>

# %% [markdown]
# By using `package_to_hub`, as we already mentionned in the former units, **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉 https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">
#
# - Copy the token
# - Run the cell below and paste the token

# %%
notebook_login()
# !git config --global credential.helper store

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥 using `package_to_hub()` function

# %%
package_to_hub(
    model=model,
    model_name=f"a2c-{env_id}",
    model_architecture="A2C",
    env_id=env_id,
    eval_env=eval_env,
    repo_id=f"hussamalafandi/a2c-{env_id}", # Change the username
    commit_message="Initial commit",
)

# %% [markdown]
# ## Take a coffee break ☕
# - You already trained your first robot that learned to move congratutlations 🥳!
# - It's **time to take a break**. Don't hesitate to **save this notebook** `File > Save a copy to Drive` to work on this second part later.

# %% [markdown]
# ## Environment 2: PandaReachDense-v2 🦾
#
# The agent we're going to train is a robotic arm that needs to do controls (moving the arm and using the end-effector).
#
# In robotics, the *end-effector* is the device at the end of a robotic arm designed to interact with the environment.
#
# In `PandaReach`, the robot must place its end-effector at a target position (green ball).
#
# We're going to use the dense version of this environment. It means we'll get a *dense reward function* that **will provide a reward at each timestep** (the closer the agent is to completing the task, the higher the reward). Contrary to a *sparse reward function* where the environment **return a reward if and only if the task is completed**.
#
# Also, we're going to use the *End-effector displacement control*, it means the **action corresponds to the displacement of the end-effector**. We don't control the individual motion of each joint (joint control).
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit8/robotics.jpg"  alt="Robotics"/>
#
#
# This way **the training will be easier**.

# %% [markdown]
# In `PandaReachDense-v2` the robotic arm must place its end-effector at a target position (green ball).

# %%
import gym

env_id = "PandaReachDense-v2"

# Create the env
env = gym.make(env_id)

# Get the state space and action space
s_size = env.observation_space.shape
a_size = env.action_space
# Out:
# pybullet build time: May 20 2022 19:45:31
# argv[0]=--background_color_red=0.8745098039215686
# argv[1]=
# argv[2]=
# argv[3]=
# argv[4]=
# argv[5]=
# argv[6]=
# argv[7]=
# argv[8]=
# argv[9]=
# argv[10]=
# argv[11]=
# argv[12]=
# argv[13]=
# argv[14]=
# argv[15]=
# argv[16]=
# argv[17]=
# argv[18]=
# argv[19]=
# argv[20]=
# argv[21]=--background_color_green=0.21176470588235294
# argv[22]=
# argv[23]=
# argv[24]=
# argv[25]=
# argv[26]=
# argv[27]=
# argv[28]=
# argv[29]=
# argv[30]=
# argv[31]=
# argv[32]=
# argv[33]=
# argv[34]=
# argv[35]=
# argv[36]=
# argv[37]=
# argv[38]=
# argv[39]=
# argv[40]=
# argv[41]=
# argv[42]=--background_color_blue=0.17647058823529413

# %%
print("_____OBSERVATION SPACE_____ \n")
print("The State Space is: ", s_size)
print("Sample observation", env.observation_space.sample()) # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# The State Space is:  None
# Sample observation OrderedDict([('achieved_goal', array([-5.7273235, -1.7929614, -9.834663 ], dtype=float32)), ('desired_goal', array([-3.6845572,  7.6906047,  9.6832905], dtype=float32)), ('observation', array([-6.321676 , -1.9572982,  2.5611975,  4.7168555, -5.8333726,
#        -5.7849846], dtype=float32))])

# %% [markdown]
# The observation space **is a dictionary with 3 different elements**:
# - `achieved_goal`: (x,y,z) position of the goal.
# - `desired_goal`: (x,y,z) distance between the goal position and the current object position.
# - `observation`: position (x,y,z) and velocity of the end-effector (vx, vy, vz).
#
# Given it's a dictionary as observation, **we will need to use a MultiInputPolicy policy instead of MlpPolicy**.

# %%
print("\n _____ACTION SPACE_____ \n")
print("The Action Space is: ", a_size)
print("Action Space Sample", env.action_space.sample()) # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# The Action Space is:  Box([-1. -1. -1.], [1. 1. 1.], (3,), float32)
# Action Space Sample [-0.26656806 -0.7850368  -0.48489165]

# %% [markdown]
# The action space is a vector with 3 values:
# - Control x, y, z movement

# %% [markdown]
# Now it's your turn:
#
# 1. Define the environment called "PandaReachDense-v2"
# 2. Make a vectorized environment
# 3. Add a wrapper to normalize the observations and rewards. [Check the documentation](https://stable-baselines3.readthedocs.io/en/master/guide/vec_envs.html#vecnormalize)
# 4. Create the A2C Model (don't forget verbose=1 to print the training logs).
# 5. Train it for 1M Timesteps
# 6. Save the model and  VecNormalize statistics when saving the agent
# 7. Evaluate your agent
# 8. Publish your trained model on the Hub 🔥 with `package_to_hub`

# %% [markdown]
# ### Solution (fill the todo)

# %%
# 1 - 2
env_id = "PandaReachDense-v2"
env = make_vec_env(env_id, n_envs=4)

# 3
env = VecNormalize(env, norm_obs=True, norm_reward=False, clip_obs=10.)

# 4
model = A2C(policy = "MultiInputPolicy",
            env = env,
            verbose=1)
# 5
model.learn(1_000_000)
# Out:
# argv[0]=--background_color_red=0.8745098039215686
# argv[1]=
# argv[2]=
# argv[3]=
# argv[4]=
# argv[5]=
# argv[6]=
# argv[7]=
# argv[8]=
# argv[9]=
# argv[10]=
# argv[11]=
# argv[12]=
# argv[13]=
# argv[14]=
# argv[15]=
# argv[16]=
# argv[17]=
# argv[18]=
# argv[19]=
# argv[20]=
# argv[21]=--background_color_green=0.21176470588235294
# argv[22]=
# argv[23]=
# argv[24]=
# argv[25]=
# argv[26]=
# argv[27]=
# argv[28]=
# argv[29]=
# argv[30]=
# argv[31]=
# argv[32]=
# argv[33]=
# argv[34]=
# argv[35]=
# argv[36]=
# argv[37]=
# argv[38]=
# argv[39]=
# argv[40]=
# argv[41]=
# argv[42]=--background_color_blue=0.17647058823529413
# argv[0]=--background_color_red=0.8745098039215686
# argv[1]=
# argv[2]=
# argv[3]=
# argv[4]=
# argv[5]=
# argv[6]=
# argv[7]=
# argv[8]=
# argv[9]=
# argv[10]=
# argv[11]=
# argv[12]=
# argv[13]=
# argv[14]=
# argv[15]=
# argv[16]=
# argv[17]=
# argv[18]=
# argv[19]=
# argv[20]=
# argv[21]=--background_color_green=0.21176470588235294
# argv[22]=
# argv[23]=
# argv[24]=
# argv[25]=
# argv[26]=
# argv[27]=
# argv[28]=
# argv[29]=
# argv[30]=
# argv[31]=
# argv[32]=
# argv[33]=
# argv[34]=
# argv[35]=
# argv[36]=
# argv[37]=
# argv[38]=
# argv[39]=
# argv[40]=
# argv[41]=
# argv[42]=--background_color_blue=0.17647058823529413
# argv[0]=--background_color_red=0.8745098039215686
# argv[1]=
# argv[2]=
# argv[3]=
# argv[4]=
# argv[5]=
# argv[6]=
# argv[7]=
# argv[8]=
# argv[9]=
# argv[10]=
# argv[11]=
# argv[12]=
# argv[13]=
# argv[14]=
# argv[15]=
# argv[16]=
# argv[17]=
# argv[18]=
# argv[19]=
# argv[20]=
# argv[21]=--background_color_green=0.21176470588235294
# argv[22]=
# argv[23]=
# argv[24]=
# argv[25]=
# argv[26]=
# argv[27]=
# argv[28]=
# argv[29]=
# argv[30]=
# argv[31]=
# argv[32]=
# argv[33]=
# argv[34]=
# argv[35]=
# argv[36]=
# argv[37]=
# argv[38]=
# argv[39]=
# argv[40]=
# argv[41]=
# argv[42]=--background_color_blue=0.17647058823529413
# argv[0]=--background_color_red=0.8745098039215686
# argv[1]=
# argv[2]=
# argv[3]=
# argv[4]=
# argv[5]=
# argv[6]=
# argv[7]=
# argv[8]=
# argv[9]=
# argv[10]=
# argv[11]=
# argv[12]=
# argv[13]=
# argv[14]=
# argv[15]=
# argv[16]=
# argv[17]=
# argv[18]=
# argv[19]=
# argv[20]=
# argv[21]=--background_color_green=0.21176470588235294
# argv[22]=
# argv[23]=
# argv[24]=
# argv[25]=
# argv[26]=
# argv[27]=
# argv[28]=
# argv[29]=
# argv[30]=
# argv[31]=
# argv[32]=
# argv[33]=
# argv[34]=
# argv[35]=
# argv[36]=
# argv[37]=
# argv[38]=
# argv[39]=
# argv[40]=
# argv[41]=
# argv[42]=--background_color_blue=0.17647058823529413
# Using cuda device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -14      |
# | time/                 |          |
# |    fps                | 494      |
# |    iterations         | 100      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -4.29    |
# |    explained_variance | 0.851    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -5.42    |
# |    std                | 1.01     |
# |    value_loss         | 2.89     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -13.1    |
# | time/                 |          |
# |    fps                | 507      |
# |    iterations         | 200      |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -4.29    |
# |    explained_variance | 0.924    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.86    |
# |    std                | 1.01     |
# |    value_loss         | 0.211    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -12.3    |
# | time/                 |          |
# |    fps                | 509      |
# |    iterations         | 300      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -4.31    |
# |    explained_variance | 0.96     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -0.577   |
# |    std                | 1.02     |
# |    value_loss         | 0.0999   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -12.1    |
# | time/                 |          |
# |    fps                | 505      |
# |    iterations         | 400      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -4.33    |
# |    explained_variance | 0.992    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.953   |
# |    std                | 1.02     |
# |    value_loss         | 0.079    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -12.3    |
# | time/                 |          |
# |    fps                | 488      |
# |    iterations         | 500      |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -4.33    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.139   |
# |    std                | 1.03     |
# |    value_loss         | 0.106    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -13.1    |
# | time/                 |          |
# |    fps                | 492      |
# |    iterations         | 600      |
# |    time_elapsed       | 24       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -4.32    |
# |    explained_variance | 0.81     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -4.12    |
# |    std                | 1.02     |
# |    value_loss         | 1.78     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -12.7    |
# | time/                 |          |
# |    fps                | 496      |
# |    iterations         | 700      |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -4.33    |
# |    explained_variance | 0.973    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -1.64    |
# |    std                | 1.02     |
# |    value_loss         | 0.25     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -11.4    |
# | time/                 |          |
# |    fps                | 496      |
# |    iterations         | 800      |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -4.32    |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.208    |
# |    std                | 1.02     |
# |    value_loss         | 0.0145   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -9.28    |
# | time/                 |          |
# |    fps                | 498      |
# |    iterations         | 900      |
# |    time_elapsed       | 36       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -4.3     |
# |    explained_variance | 0.988    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.972   |
# |    std                | 1.01     |
# |    value_loss         | 0.136    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -9.18    |
# | time/                 |          |
# |    fps                | 498      |
# |    iterations         | 1000     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -4.29    |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -1.13    |
# |    std                | 1.01     |
# |    value_loss         | 0.144    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -9.1     |
# | time/                 |          |
# |    fps                | 501      |
# |    iterations         | 1100     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -4.3     |
# |    explained_variance | 0.987    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.0483   |
# |    std                | 1.02     |
# |    value_loss         | 0.0843   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -8.25    |
# | time/                 |          |
# |    fps                | 504      |
# |    iterations         | 1200     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -4.3     |
# |    explained_variance | 0.954    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -1.2     |
# |    std                | 1.02     |
# |    value_loss         | 0.206    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -7.55    |
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 1300     |
# |    time_elapsed       | 51       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -4.31    |
# |    explained_variance | 0.887    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.131   |
# |    std                | 1.02     |
# |    value_loss         | 0.214    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -7.75    |
# | time/                 |          |
# |    fps                | 505      |
# |    iterations         | 1400     |
# |    time_elapsed       | 55       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -4.29    |
# |    explained_variance | 0.994    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.462   |
# |    std                | 1.01     |
# |    value_loss         | 0.0597   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -7.29    |
# | time/                 |          |
# |    fps                | 506      |
# |    iterations         | 1500     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -4.27    |
# |    explained_variance | 0.913    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.00801  |
# |    std                | 1.01     |
# |    value_loss         | 0.0412   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -6.69    |
# | time/                 |          |
# |    fps                | 508      |
# |    iterations         | 1600     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -4.28    |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.998   |
# |    std                | 1.01     |
# |    value_loss         | 0.0931   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -6.14    |
# | time/                 |          |
# |    fps                | 510      |
# |    iterations         | 1700     |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -4.26    |
# |    explained_variance | 0.995    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.558   |
# |    std                | 1        |
# |    value_loss         | 0.0339   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.67    |
# | time/                 |          |
# |    fps                | 514      |
# |    iterations         | 1800     |
# |    time_elapsed       | 70       |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -4.22    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.554   |
# |    std                | 0.988    |
# |    value_loss         | 0.0174   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.81    |
# | time/                 |          |
# |    fps                | 515      |
# |    iterations         | 1900     |
# |    time_elapsed       | 73       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -4.2     |
# |    explained_variance | 0.966    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.241   |
# |    std                | 0.984    |
# |    value_loss         | 0.0185   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.06    |
# | time/                 |          |
# |    fps                | 518      |
# |    iterations         | 2000     |
# |    time_elapsed       | 77       |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -4.16    |
# |    explained_variance | 0.605    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0478  |
# |    std                | 0.972    |
# |    value_loss         | 0.0136   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -3.34    |
# | time/                 |          |
# |    fps                | 518      |
# |    iterations         | 2100     |
# |    time_elapsed       | 81       |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -4.12    |
# |    explained_variance | 0.986    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.0436  |
# |    std                | 0.958    |
# |    value_loss         | 0.00755  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -3.02    |
# | time/                 |          |
# |    fps                | 519      |
# |    iterations         | 2200     |
# |    time_elapsed       | 84       |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -4.07    |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.0278  |
# |    std                | 0.941    |
# |    value_loss         | 0.00264  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.68    |
# | time/                 |          |
# |    fps                | 522      |
# |    iterations         | 2300     |
# |    time_elapsed       | 88       |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -4.05    |
# |    explained_variance | 0.99     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.305    |
# |    std                | 0.934    |
# |    value_loss         | 0.0129   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.51    |
# | time/                 |          |
# |    fps                | 524      |
# |    iterations         | 2400     |
# |    time_elapsed       | 91       |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -4       |
# |    explained_variance | 0.982    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.0272   |
# |    std                | 0.918    |
# |    value_loss         | 0.00295  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.37    |
# | time/                 |          |
# |    fps                | 527      |
# |    iterations         | 2500     |
# |    time_elapsed       | 94       |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -3.95    |
# |    explained_variance | 0.774    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.109   |
# |    std                | 0.905    |
# |    value_loss         | 0.00621  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.26    |
# | time/                 |          |
# |    fps                | 529      |
# |    iterations         | 2600     |
# |    time_elapsed       | 98       |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -3.9     |
# |    explained_variance | 0.885    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.099   |
# |    std                | 0.889    |
# |    value_loss         | 0.00331  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.19    |
# | time/                 |          |
# |    fps                | 531      |
# |    iterations         | 2700     |
# |    time_elapsed       | 101      |
# |    total_timesteps    | 54000    |
# | train/                |          |
# |    entropy_loss       | -3.84    |
# |    explained_variance | 0.824    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.192    |
# |    std                | 0.87     |
# |    value_loss         | 0.0169   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.12    |
# | time/                 |          |
# |    fps                | 532      |
# |    iterations         | 2800     |
# |    time_elapsed       | 105      |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -3.79    |
# |    explained_variance | 0.794    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.0646  |
# |    std                | 0.859    |
# |    value_loss         | 0.00226  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.08    |
# | time/                 |          |
# |    fps                | 534      |
# |    iterations         | 2900     |
# |    time_elapsed       | 108      |
# |    total_timesteps    | 58000    |
# | train/                |          |
# |    entropy_loss       | -3.75    |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.0755   |
# |    std                | 0.845    |
# |    value_loss         | 0.00148  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.08    |
# | time/                 |          |
# |    fps                | 535      |
# |    iterations         | 3000     |
# |    time_elapsed       | 111      |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -3.72    |
# |    explained_variance | 0.991    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.0664  |
# |    std                | 0.837    |
# |    value_loss         | 0.0023   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.01    |
# | time/                 |          |
# |    fps                | 535      |
# |    iterations         | 3100     |
# |    time_elapsed       | 115      |
# |    total_timesteps    | 62000    |
# | train/                |          |
# |    entropy_loss       | -3.66    |
# |    explained_variance | 0.883    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.0916  |
# |    std                | 0.822    |
# |    value_loss         | 0.00153  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.93    |
# | time/                 |          |
# |    fps                | 536      |
# |    iterations         | 3200     |
# |    time_elapsed       | 119      |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -3.63    |
# |    explained_variance | 0.898    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.0737   |
# |    std                | 0.813    |
# |    value_loss         | 0.00336  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.88    |
# | time/                 |          |
# |    fps                | 536      |
# |    iterations         | 3300     |
# |    time_elapsed       | 122      |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -3.59    |
# |    explained_variance | 0.922    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | -0.0543  |
# |    std                | 0.801    |
# |    value_loss         | 0.00289  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.85    |
# | time/                 |          |
# |    fps                | 537      |
# |    iterations         | 3400     |
# |    time_elapsed       | 126      |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -3.52    |
# |    explained_variance | 0.992    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.123    |
# |    std                | 0.783    |
# |    value_loss         | 0.00331  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.84    |
# | time/                 |          |
# |    fps                | 538      |
# |    iterations         | 3500     |
# |    time_elapsed       | 130      |
# |    total_timesteps    | 70000    |
# | train/                |          |
# |    entropy_loss       | -3.48    |
# |    explained_variance | 0.969    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.0276   |
# |    std                | 0.773    |
# |    value_loss         | 0.00173  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.82    |
# | time/                 |          |
# |    fps                | 539      |
# |    iterations         | 3600     |
# |    time_elapsed       | 133      |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -3.44    |
# |    explained_variance | 0.994    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.0992   |
# |    std                | 0.761    |
# |    value_loss         | 0.00137  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.79    |
# | time/                 |          |
# |    fps                | 540      |
# |    iterations         | 3700     |
# |    time_elapsed       | 137      |
# |    total_timesteps    | 74000    |
# | train/                |          |
# |    entropy_loss       | -3.39    |
# |    explained_variance | 0.983    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.0748   |
# |    std                | 0.749    |
# |    value_loss         | 0.00177  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.76    |
# | time/                 |          |
# |    fps                | 540      |
# |    iterations         | 3800     |
# |    time_elapsed       | 140      |
# |    total_timesteps    | 76000    |
# | train/                |          |
# |    entropy_loss       | -3.35    |
# |    explained_variance | 0.966    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.112    |
# |    std                | 0.74     |
# |    value_loss         | 0.00195  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.74    |
# | time/                 |          |
# |    fps                | 540      |
# |    iterations         | 3900     |
# |    time_elapsed       | 144      |
# |    total_timesteps    | 78000    |
# | train/                |          |
# |    entropy_loss       | -3.32    |
# |    explained_variance | 0.794    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.0531  |
# |    std                | 0.733    |
# |    value_loss         | 0.00241  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.72    |
# | time/                 |          |
# |    fps                | 540      |
# |    iterations         | 4000     |
# |    time_elapsed       | 148      |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -3.27    |
# |    explained_variance | 0.974    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.0119   |
# |    std                | 0.72     |
# |    value_loss         | 0.000563 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.77    |
# | time/                 |          |
# |    fps                | 538      |
# |    iterations         | 4100     |
# |    time_elapsed       | 152      |
# |    total_timesteps    | 82000    |
# | train/                |          |
# |    entropy_loss       | -3.24    |
# |    explained_variance | 0.96     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.0186  |
# |    std                | 0.712    |
# |    value_loss         | 0.000661 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.77    |
# | time/                 |          |
# |    fps                | 536      |
# |    iterations         | 4200     |
# |    time_elapsed       | 156      |
# |    total_timesteps    | 84000    |
# | train/                |          |
# |    entropy_loss       | -3.21    |
# |    explained_variance | 0.961    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.094   |
# |    std                | 0.705    |
# |    value_loss         | 0.00245  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.72    |
# | time/                 |          |
# |    fps                | 535      |
# |    iterations         | 4300     |
# |    time_elapsed       | 160      |
# |    total_timesteps    | 86000    |
# | train/                |          |
# |    entropy_loss       | -3.18    |
# |    explained_variance | 0.979    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -0.0249  |
# |    std                | 0.698    |
# |    value_loss         | 0.00116  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.69    |
# | time/                 |          |
# |    fps                | 536      |
# |    iterations         | 4400     |
# |    time_elapsed       | 164      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -3.14    |
# |    explained_variance | 0.995    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.0036  |
# |    std                | 0.691    |
# |    value_loss         | 0.000396 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.66    |
# | time/                 |          |
# |    fps                | 536      |
# |    iterations         | 4500     |
# |    time_elapsed       | 167      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -3.09    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | 0.0491   |
# |    std                | 0.679    |
# |    value_loss         | 0.000722 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.66    |
# | time/                 |          |
# |    fps                | 535      |
# |    iterations         | 4600     |
# |    time_elapsed       | 171      |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -3.05    |
# |    explained_variance | 0.984    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | 0.0385   |
# |    std                | 0.67     |
# |    value_loss         | 0.000415 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.63    |
# | time/                 |          |
# |    fps                | 534      |
# |    iterations         | 4700     |
# |    time_elapsed       | 175      |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -3.01    |
# |    explained_variance | 0.88     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | -0.0627  |
# |    std                | 0.66     |
# |    value_loss         | 0.00151  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.66    |
# | time/                 |          |
# |    fps                | 534      |
# |    iterations         | 4800     |
# |    time_elapsed       | 179      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -2.99    |
# |    explained_variance | 0.983    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 0.0806   |
# |    std                | 0.656    |
# |    value_loss         | 0.00134  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.66    |
# | time/                 |          |
# |    fps                | 535      |
# |    iterations         | 4900     |
# |    time_elapsed       | 182      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -2.95    |
# |    explained_variance | 0.992    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -0.0298  |
# |    std                | 0.647    |
# |    value_loss         | 0.00117  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.7     |
# | time/                 |          |
# |    fps                | 535      |
# |    iterations         | 5000     |
# |    time_elapsed       | 186      |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -2.92    |
# |    explained_variance | 0.973    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | -0.0221  |
# |    std                | 0.641    |
# |    value_loss         | 0.00265  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.71    |
# | time/                 |          |
# |    fps                | 532      |
# |    iterations         | 5100     |
# |    time_elapsed       | 191      |
# |    total_timesteps    | 102000   |
# | train/                |          |
# |    entropy_loss       | -2.89    |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.028   |
# |    std                | 0.635    |
# |    value_loss         | 0.000686 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.68    |
# | time/                 |          |
# |    fps                | 532      |
# |    iterations         | 5200     |
# |    time_elapsed       | 195      |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -2.84    |
# |    explained_variance | 0.983    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.0132   |
# |    std                | 0.625    |
# |    value_loss         | 0.000726 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.64    |
# | time/                 |          |
# |    fps                | 533      |
# |    iterations         | 5300     |
# |    time_elapsed       | 198      |
# |    total_timesteps    | 106000   |
# | train/                |          |
# |    entropy_loss       | -2.81    |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | 0.0303   |
# |    std                | 0.618    |
# |    value_loss         | 0.000536 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.61    |
# | time/                 |          |
# |    fps                | 533      |
# |    iterations         | 5400     |
# |    time_elapsed       | 202      |
# |    total_timesteps    | 108000   |
# | train/                |          |
# |    entropy_loss       | -2.79    |
# |    explained_variance | 0.974    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | -0.0135  |
# |    std                | 0.615    |
# |    value_loss         | 0.00131  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.57    |
# | time/                 |          |
# |    fps                | 533      |
# |    iterations         | 5500     |
# |    time_elapsed       | 206      |
# |    total_timesteps    | 110000   |
# | train/                |          |
# |    entropy_loss       | -2.77    |
# |    explained_variance | 0.933    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | -0.0558  |
# |    std                | 0.611    |
# |    value_loss         | 0.000858 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.59    |
# | time/                 |          |
# |    fps                | 534      |
# |    iterations         | 5600     |
# |    time_elapsed       | 209      |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -2.76    |
# |    explained_variance | -0.493   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | -0.0361  |
# |    std                | 0.607    |
# |    value_loss         | 0.00122  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.6     |
# | time/                 |          |
# |    fps                | 534      |
# |    iterations         | 5700     |
# |    time_elapsed       | 213      |
# |    total_timesteps    | 114000   |
# | train/                |          |
# |    entropy_loss       | -2.73    |
# |    explained_variance | 0.991    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | -0.0284  |
# |    std                | 0.601    |
# |    value_loss         | 0.00118  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.61    |
# | time/                 |          |
# |    fps                | 533      |
# |    iterations         | 5800     |
# |    time_elapsed       | 217      |
# |    total_timesteps    | 116000   |
# | train/                |          |
# |    entropy_loss       | -2.68    |
# |    explained_variance | 0.99     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | -0.078   |
# |    std                | 0.593    |
# |    value_loss         | 0.00112  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.59    |
# | time/                 |          |
# |    fps                | 533      |
# |    iterations         | 5900     |
# |    time_elapsed       | 221      |
# |    total_timesteps    | 118000   |
# | train/                |          |
# |    entropy_loss       | -2.66    |
# |    explained_variance | 0.993    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.00337  |
# |    std                | 0.589    |
# |    value_loss         | 0.000829 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.57    |
# | time/                 |          |
# |    fps                | 533      |
# |    iterations         | 6000     |
# |    time_elapsed       | 224      |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -2.62    |
# |    explained_variance | 0.993    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.0262   |
# |    std                | 0.581    |
# |    value_loss         | 0.000519 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.54    |
# | time/                 |          |
# |    fps                | 534      |
# |    iterations         | 6100     |
# |    time_elapsed       | 228      |
# |    total_timesteps    | 122000   |
# | train/                |          |
# |    entropy_loss       | -2.58    |
# |    explained_variance | 0.978    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -0.00997 |
# |    std                | 0.573    |
# |    value_loss         | 0.00157  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.56    |
# | time/                 |          |
# |    fps                | 534      |
# |    iterations         | 6200     |
# |    time_elapsed       | 232      |
# |    total_timesteps    | 124000   |
# | train/                |          |
# |    entropy_loss       | -2.54    |
# |    explained_variance | 0.994    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.00734 |
# |    std                | 0.565    |
# |    value_loss         | 0.00043  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.59    |
# | time/                 |          |
# |    fps                | 535      |
# |    iterations         | 6300     |
# |    time_elapsed       | 235      |
# |    total_timesteps    | 126000   |
# | train/                |          |
# |    entropy_loss       | -2.5     |
# |    explained_variance | 0.957    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | -0.0968  |
# |    std                | 0.559    |
# |    value_loss         | 0.00252  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.58    |
# | time/                 |          |
# |    fps                | 535      |
# |    iterations         | 6400     |
# |    time_elapsed       | 238      |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -2.47    |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | -0.0139  |
# |    std                | 0.552    |
# |    value_loss         | 0.000458 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.56    |
# | time/                 |          |
# |    fps                | 536      |
# |    iterations         | 6500     |
# |    time_elapsed       | 242      |
# |    total_timesteps    | 130000   |
# | train/                |          |
# |    entropy_loss       | -2.42    |
# |    explained_variance | 0.973    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.018   |
# |    std                | 0.543    |
# |    value_loss         | 0.00109  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.57    |
# | time/                 |          |
# |    fps                | 536      |
# |    iterations         | 6600     |
# |    time_elapsed       | 245      |
# |    total_timesteps    | 132000   |
# | train/                |          |
# |    entropy_loss       | -2.38    |
# |    explained_variance | 0.99     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.0117  |
# |    std                | 0.536    |
# |    value_loss         | 0.00171  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.55    |
# | time/                 |          |
# |    fps                | 537      |
# |    iterations         | 6700     |
# |    time_elapsed       | 249      |
# |    total_timesteps    | 134000   |
# | train/                |          |
# |    entropy_loss       | -2.34    |
# |    explained_variance | 0.655    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -0.0248  |
# |    std                | 0.529    |
# |    value_loss         | 0.000695 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.56    |
# | time/                 |          |
# |    fps                | 538      |
# |    iterations         | 6800     |
# |    time_elapsed       | 252      |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -2.29    |
# |    explained_variance | 0.974    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | -0.00979 |
# |    std                | 0.52     |
# |    value_loss         | 0.000822 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.54    |
# | time/                 |          |
# |    fps                | 538      |
# |    iterations         | 6900     |
# |    time_elapsed       | 256      |
# |    total_timesteps    | 138000   |
# | train/                |          |
# |    entropy_loss       | -2.26    |
# |    explained_variance | 0.994    |
# |    learning_rate      | 0.0007   |
# ...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -3.16    |
# | time/                 |          |
# |    fps                | 466      |
# |    iterations         | 47700    |
# |    time_elapsed       | 2047     |
# |    total_timesteps    | 954000   |
# | train/                |          |
# |    entropy_loss       | 5.62     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47699    |
# |    policy_loss        | -0.0402  |
# |    std                | 0.0374   |
# |    value_loss         | 0.00445  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.27    |
# | time/                 |          |
# |    fps                | 465      |
# |    iterations         | 47800    |
# |    time_elapsed       | 2051     |
# |    total_timesteps    | 956000   |
# | train/                |          |
# |    entropy_loss       | 5.61     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47799    |
# |    policy_loss        | 0.176    |
# |    std                | 0.0375   |
# |    value_loss         | 0.00216  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.7     |
# | time/                 |          |
# |    fps                | 465      |
# |    iterations         | 47900    |
# |    time_elapsed       | 2056     |
# |    total_timesteps    | 958000   |
# | train/                |          |
# |    entropy_loss       | 5.64     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47899    |
# |    policy_loss        | 0.0583   |
# |    std                | 0.0371   |
# |    value_loss         | 0.00135  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.93    |
# | time/                 |          |
# |    fps                | 465      |
# |    iterations         | 48000    |
# |    time_elapsed       | 2061     |
# |    total_timesteps    | 960000   |
# | train/                |          |
# |    entropy_loss       | 5.63     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 47999    |
# |    policy_loss        | -0.0776  |
# |    std                | 0.0372   |
# |    value_loss         | 0.00585  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.96    |
# | time/                 |          |
# |    fps                | 465      |
# |    iterations         | 48100    |
# |    time_elapsed       | 2065     |
# |    total_timesteps    | 962000   |
# | train/                |          |
# |    entropy_loss       | 5.62     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48099    |
# |    policy_loss        | 0.103    |
# |    std                | 0.0374   |
# |    value_loss         | 0.00286  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -6.75    |
# | time/                 |          |
# |    fps                | 465      |
# |    iterations         | 48200    |
# |    time_elapsed       | 2070     |
# |    total_timesteps    | 964000   |
# | train/                |          |
# |    entropy_loss       | 5.6      |
# |    explained_variance | 0.936    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48199    |
# |    policy_loss        | 0.366    |
# |    std                | 0.0376   |
# |    value_loss         | 2.37     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -6.67    |
# | time/                 |          |
# |    fps                | 465      |
# |    iterations         | 48300    |
# |    time_elapsed       | 2074     |
# |    total_timesteps    | 966000   |
# | train/                |          |
# |    entropy_loss       | 5.62     |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48299    |
# |    policy_loss        | -0.451   |
# |    std                | 0.0374   |
# |    value_loss         | 0.0206   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.21    |
# | time/                 |          |
# |    fps                | 465      |
# |    iterations         | 48400    |
# |    time_elapsed       | 2079     |
# |    total_timesteps    | 968000   |
# | train/                |          |
# |    entropy_loss       | 5.64     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48399    |
# |    policy_loss        | 0.367    |
# |    std                | 0.0371   |
# |    value_loss         | 0.00864  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -3.13    |
# | time/                 |          |
# |    fps                | 465      |
# |    iterations         | 48500    |
# |    time_elapsed       | 2084     |
# |    total_timesteps    | 970000   |
# | train/                |          |
# |    entropy_loss       | 5.64     |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48499    |
# |    policy_loss        | -0.00618 |
# |    std                | 0.0372   |
# |    value_loss         | 0.00119  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -3.57    |
# | time/                 |          |
# |    fps                | 465      |
# |    iterations         | 48600    |
# |    time_elapsed       | 2089     |
# |    total_timesteps    | 972000   |
# | train/                |          |
# |    entropy_loss       | 5.65     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48599    |
# |    policy_loss        | -0.0512  |
# |    std                | 0.037    |
# |    value_loss         | 0.00439  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -3.23    |
# | time/                 |          |
# |    fps                | 465      |
# |    iterations         | 48700    |
# |    time_elapsed       | 2093     |
# |    total_timesteps    | 974000   |
# | train/                |          |
# |    entropy_loss       | 5.66     |
# |    explained_variance | 0.979    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48699    |
# |    policy_loss        | -0.115   |
# |    std                | 0.0369   |
# |    value_loss         | 0.0051   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -3.17    |
# | time/                 |          |
# |    fps                | 465      |
# |    iterations         | 48800    |
# |    time_elapsed       | 2098     |
# |    total_timesteps    | 976000   |
# | train/                |          |
# |    entropy_loss       | 5.64     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48799    |
# |    policy_loss        | 0.0691   |
# |    std                | 0.0371   |
# |    value_loss         | 0.00308  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.94    |
# | time/                 |          |
# |    fps                | 464      |
# |    iterations         | 48900    |
# |    time_elapsed       | 2103     |
# |    total_timesteps    | 978000   |
# | train/                |          |
# |    entropy_loss       | 5.64     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48899    |
# |    policy_loss        | 0.069    |
# |    std                | 0.0371   |
# |    value_loss         | 0.00225  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -3.07    |
# | time/                 |          |
# |    fps                | 464      |
# |    iterations         | 49000    |
# |    time_elapsed       | 2108     |
# |    total_timesteps    | 980000   |
# | train/                |          |
# |    entropy_loss       | 5.63     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 48999    |
# |    policy_loss        | -0.0982  |
# |    std                | 0.0372   |
# |    value_loss         | 0.000651 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -3.18    |
# | time/                 |          |
# |    fps                | 464      |
# |    iterations         | 49100    |
# |    time_elapsed       | 2113     |
# |    total_timesteps    | 982000   |
# | train/                |          |
# |    entropy_loss       | 5.61     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49099    |
# |    policy_loss        | 0.0904   |
# |    std                | 0.0374   |
# |    value_loss         | 0.00207  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -3.18    |
# | time/                 |          |
# |    fps                | 464      |
# |    iterations         | 49200    |
# |    time_elapsed       | 2117     |
# |    total_timesteps    | 984000   |
# | train/                |          |
# |    entropy_loss       | 5.62     |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49199    |
# |    policy_loss        | -0.0274  |
# |    std                | 0.0374   |
# |    value_loss         | 0.00762  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -3.24    |
# | time/                 |          |
# |    fps                | 464      |
# |    iterations         | 49300    |
# |    time_elapsed       | 2121     |
# |    total_timesteps    | 986000   |
# | train/                |          |
# |    entropy_loss       | 5.61     |
# |    explained_variance | 0.993    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49299    |
# |    policy_loss        | -0.0766  |
# |    std                | 0.0374   |
# |    value_loss         | 0.00446  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -3.05    |
# | time/                 |          |
# |    fps                | 464      |
# |    iterations         | 49400    |
# |    time_elapsed       | 2125     |
# |    total_timesteps    | 988000   |
# | train/                |          |
# |    entropy_loss       | 5.63     |
# |    explained_variance | 1        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49399    |
# |    policy_loss        | 0.104    |
# |    std                | 0.0372   |
# |    value_loss         | 0.000855 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.84    |
# | time/                 |          |
# |    fps                | 464      |
# |    iterations         | 49500    |
# |    time_elapsed       | 2130     |
# |    total_timesteps    | 990000   |
# | train/                |          |
# |    entropy_loss       | 5.63     |
# |    explained_variance | 0.991    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49499    |
# |    policy_loss        | -0.0584  |
# |    std                | 0.0372   |
# |    value_loss         | 0.00134  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.62    |
# | time/                 |          |
# |    fps                | 464      |
# |    iterations         | 49600    |
# |    time_elapsed       | 2134     |
# |    total_timesteps    | 992000   |
# | train/                |          |
# |    entropy_loss       | 5.61     |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49599    |
# |    policy_loss        | -0.0547  |
# |    std                | 0.0374   |
# |    value_loss         | 0.00237  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.6     |
# | time/                 |          |
# |    fps                | 464      |
# |    iterations         | 49700    |
# |    time_elapsed       | 2137     |
# |    total_timesteps    | 994000   |
# | train/                |          |
# |    entropy_loss       | 5.61     |
# |    explained_variance | 0.994    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49699    |
# |    policy_loss        | -0.235   |
# |    std                | 0.0375   |
# |    value_loss         | 0.0122   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.73    |
# | time/                 |          |
# |    fps                | 465      |
# |    iterations         | 49800    |
# |    time_elapsed       | 2141     |
# |    total_timesteps    | 996000   |
# | train/                |          |
# |    entropy_loss       | 5.6      |
# |    explained_variance | 0.958    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49799    |
# |    policy_loss        | 0.191    |
# |    std                | 0.0375   |
# |    value_loss         | 0.0297   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -3.01    |
# | time/                 |          |
# |    fps                | 465      |
# |    iterations         | 49900    |
# |    time_elapsed       | 2145     |
# |    total_timesteps    | 998000   |
# | train/                |          |
# |    entropy_loss       | 5.62     |
# |    explained_variance | 0.985    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49899    |
# |    policy_loss        | -0.187   |
# |    std                | 0.0373   |
# |    value_loss         | 0.0154   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.96    |
# | time/                 |          |
# |    fps                | 465      |
# |    iterations         | 50000    |
# |    time_elapsed       | 2149     |
# |    total_timesteps    | 1000000  |
# | train/                |          |
# |    entropy_loss       | 5.65     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 49999    |
# |    policy_loss        | -0.208   |
# |    std                | 0.0369   |
# |    value_loss         | 0.00628  |
# ------------------------------------

# %%
# 6
model_name = "a2c-PandaReachDense-v2"; 
model.save(model_name)
env.save("vec_normalize.pkl")

# 7
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

# Load the saved statistics
eval_env = DummyVecEnv([lambda: gym.make("PandaReachDense-v2")])
eval_env = VecNormalize.load("vec_normalize.pkl", eval_env)

#  do not update them at test time
eval_env.training = False
# reward normalization is not needed at test time
eval_env.norm_reward = False

# Load the agent
model = A2C.load(model_name)

mean_reward, std_reward = evaluate_policy(model, eval_env)

print(f"Mean reward = {mean_reward:.2f} +/- {std_reward:.2f}")

# 8
package_to_hub(
    model=model,
    model_name=f"a2c-{env_id}",
    model_architecture="A2C",
    env_id=env_id,
    eval_env=eval_env,
    repo_id=f"hussamalafandi/a2c-{env_id}", # TODO: Change the username
    commit_message="Initial commit",
)
# Out:
# argv[0]=--background_color_red=0.8745098039215686
# argv[1]=
# argv[2]=
# argv[3]=
# argv[4]=
# argv[5]=
# argv[6]=
# argv[7]=
# argv[8]=
# argv[9]=
# argv[10]=
# argv[11]=
# argv[12]=
# argv[13]=
# argv[14]=
# argv[15]=
# argv[16]=
# argv[17]=
# argv[18]=
# argv[19]=
# argv[20]=
# argv[21]=--background_color_green=0.21176470588235294
# argv[22]=
# argv[23]=
# argv[24]=
# argv[25]=
# argv[26]=
# argv[27]=
# argv[28]=
# argv[29]=
# argv[30]=
# argv[31]=
# argv[32]=
# argv[33]=
# argv[34]=
# argv[35]=
# argv[36]=
# argv[37]=
# argv[38]=
# argv[39]=
# argv[40]=
# argv[41]=
# argv[42]=--background_color_blue=0.17647058823529413
# /home/hussam/miniconda3/envs/hf-course/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Mean reward = -2.65 +/- 0.52
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# /home/hussam/miniconda3/envs/hf-course/lib/python3.9/site-packages/panda_gym/pybullet.py:97: UserWarning: The use of the render method is not recommended when the environment has not been created with render=True. The rendering will probably be weird. Prefer making the environment with option `render=True`. For example: `env = gym.make('PandaReach-v2', render=True)`.
#   warnings.warn(
# /home/hussam/miniconda3/envs/hf-course/lib/python3.9/site-packages/panda_gym/pybullet.py:97: UserWarning: The use of the render method is not recommended when the environment has not been created with render=True. The rendering will probably be weird. Prefer making the environment with option `render=True`. For example: `env = gym.make('PandaReach-v2', render=True)`.
#   warnings.warn(
# Saving video to /tmp/tmpt9_mek_6/-step-0-to-step-1000.mp4
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   WARNING: library configuration mismatch
#   avcodec     configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared --enable-version3 --disable-doc --disable-programs --enable-libaribb24 --enable-libopencore_amrnb --enable-libopencore_amrwb --enable-libtesseract --enable-libvo_amrwbenc --enable-libsmbclient
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/tmp/tmpt9_mek_6/-step-0-to-step-1000.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:33.37, start: 0.000000, bitrate: 189 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 720x480, 186 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x557d347f95c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x557d347f95c0] profile High, level 3.0, 4:2:0, 8-bit
# [libx264 @ 0x557d347f95c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=15 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/tmp/tmpdu5h7bk3/replay.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 720x480, q=2-31, 30 fps, 15360 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame= 1001 fps=952 q=-1.0 Lsize=     749kB time=00:00:33.26 bitrate= 184.5kbits/s speed=31.6x
# video:737kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.701228%
# [libx264 @ 0x557d347f95c0] frame I:5     Avg QP:19.32  size:  6700
# [libx264 @ 0x557d347f95c0] frame P:260   Avg QP:26.85  size:  1036
# [libx264 @ 0x557d347f95c0] frame B:736   Avg QP:31.62  size:   612
# [libx264 @ 0x557d347f95c0] consecutive B-frames:  1.2%  1.8%  1.5% 95.5%
# [libx264 @ 0x557d347f95c0] mb I  I16..4:  6.4% 77.7% 15.9%
# [libx264 @ 0x557d347f95c0] mb P  I16..4:  0.1%  0.5%  0.3%  P16..4:  3.3%  1.9%  1.2%  0.0%  0.0%    skip:92.8%
# [libx264 @ 0x557d347f95c0] mb B  I16..4:  0.0%  0.1%  0.1%  B16..8:  3.5%  1.9%  0.7%  direct: 0.2%  skip:93.5%  L0:52.3% L1:44.5% BI: 3.2%
# [libx264 @ 0x557d347f95c0] 8x8 transform intra:66.6% inter:8.3%
# [libx264 @ 0x557d347f95c0] coded y,uvDC,uvAC intra: 16.2% 2.6% 1.4% inter: 1.1% 0.1% 0.1%
# [libx264 @ 0x557d347f95c0] i16 v,h,dc,p: 61% 14% 24%  0%
# [libx264 @ 0x557d347f95c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 46% 12% 41%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x557d347f95c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 18% 26%  3%  5%  4%  7%  2%  5%
# [libx264 @ 0x557d347f95c0] i8c dc,h,v,p: 96%  2%  2%  0%
# [libx264 @ 0x557d347f95c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x557d347f95c0] ref P L0: 52.0%  3.3% 26.4% 18.3%
# [libx264 @ 0x557d347f95c0] ref B L0: 65.9% 24.7%  9.5%
# [libx264 @ 0x557d347f95c0] ref B L1: 87.8% 12.2%
# [libx264 @ 0x557d347f95c0] kb/s:180.67
# Exception ignored in: <function VecVideoRecorder.__del__ at 0x7f1f5b59d5e0>
# Traceback (most recent call last):
#   File "/home/hussam/miniconda3/envs/hf-course/lib/python3.9/site-packages/stable_baselines3/common/vec_env/vec_video_recorder.py", line 112, in __del__
#     self.close()
#   File "/home/hussam/miniconda3/envs/hf-course/lib/python3.9/site-packages/stable_baselines3/common/vec_env/vec_video_recorder.py", line 108, in close
#     VecEnvWrapper.close(self)
#   File "/home/hussam/miniconda3/envs/hf-course/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py", line 279, in close
#     return self.venv.close()
#   File "/home/hussam/miniconda3/envs/hf-course/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py", line 279, in close
#     return self.venv.close()
#   File "/home/hussam/miniconda3/envs/hf-course/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py", line 80, in close
#     env.close()
#   File "/home/hussam/miniconda3/envs/hf-course/lib/python3.9/site-packages/gym/core.py", line 298, in close
#     return self.env.close()
#   File "/home/hussam/miniconda3/envs/hf-course/lib/python3.9/site-packages/panda_gym/envs/core.py", line 279, in close
#     self.sim.close()
#   File "/home/hussam/miniconda3/envs/hf-course/lib/python3.9/site-packages/panda_gym/pybullet.py", line 59, in close
#     self.physics_client.disconnect()
# pybullet.error: Not connected to physics server.
# ℹ Pushing repo hussamalafandi/a2c-PandaReachDense-v2 to the Hugging
# Face Hub
# a2c-PandaReachDense-v2.zip:   0%|          | 0.00/108k [00:00<?, ?B/s]
# pytorch_variables.pth:   0%|          | 0.00/431 [00:00<?, ?B/s]
# policy.pth:   0%|          | 0.00/46.0k [00:00<?, ?B/s]
# vec_normalize.pkl:   0%|          | 0.00/2.38k [00:00<?, ?B/s]
# policy.optimizer.pth:   0%|          | 0.00/44.7k [00:00<?, ?B/s]
# Upload 5 LFS files:   0%|          | 0/5 [00:00<?, ?it/s]
# ℹ Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/hussamalafandi/a2c-PandaReachDense-v2/tree/main/
# 'https://huggingface.co/hussamalafandi/a2c-PandaReachDense-v2/tree/main/'

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**! Why not trying  `HalfCheetahBulletEnv-v0` for PyBullet and `PandaPickAndPlace-v1` for Panda-Gym?
#
# If you want to try more advanced tasks for panda-gym, you need to check what was done using **TQC or SAC** (a more sample-efficient algorithm suited for robotics tasks). In real robotics, you'll use a more sample-efficient algorithm for a simple reason: contrary to a simulation **if you move your robotic arm too much, you have a risk of breaking it**.
#
# PandaPickAndPlace-v1: https://huggingface.co/sb3/tqc-PandaPickAndPlace-v1
#
# And don't hesitate to check panda-gym documentation here: https://panda-gym.readthedocs.io/en/latest/usage/train_with_sb3.html
#
# Here are some ideas to achieve so:
# * Train more steps
# * Try different hyperparameters by looking at what your classmates have done 👉 https://huggingface.co/models?other=https://huggingface.co/models?other=AntBulletEnv-v0
# * **Push your new trained model** on the Hub 🔥

# %% [markdown]
# See you on Unit 7! 🔥
# ## Keep learning, stay awesome 🤗
